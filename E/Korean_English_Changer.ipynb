# %% [markdown]
# # 동의어사전 - 한글/영어 키보드 기준 변환

# %% [markdown]
# 2021-01-28
# &nbsp;
# 주어진 키워드를..
# - 한글로 적혀진 것 > 키보드 기준 영어로
# - 영어로 적혀진 것 > 키보드 기준 한글로
#
# 변환하는 작업을 하였다.
# 유입되는 검색어 중에 한/영 전환이 필요한 키워드를 찾기 위한 것이다.

# %%
import pandas as pd
import re
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# 파일불러오기

# %%
sd = pd.read_excel('data.xlsx')

# %% [markdown]
# ## 한글 → 영어로 변환

# %% [markdown]
# 1. 자소분리
# 사과 → ㅅㅏㄱㅘ

# %%
from jamo import h2j, j2hcj

sd['자소분리'] = sd['keyword'].apply(lambda x: j2hcj(h2j(x)) if type(x) == str else x)

# %% [markdown]
# 2. 한글-영문 키보드입력에 맞추어 변환

# %%
keyboard = {'ㄱ':'r', 'ㄲ':'R', 'ㄴ':'s', 'ㄷ':'e', 'ㄸ':'E', 'ㄹ':'f', 'ㅁ':'a', 'ㅂ':'q', 'ㅃ':'Q', 'ㅅ':'t', 'ㅆ':'T',
           'ㅇ':'d', 'ㅈ':'w', 'ㅉ':'W', 'ㅊ':'c', 'ㅋ':'z', 'ㅌ':'x', 'ㅍ':'v', 'ㅎ':'g',
           'ㅏ':'k', 'ㅐ':'o', 'ㅑ':'i', 'ㅒ':'O', 'ㅓ':'j', 'ㅔ':'p', 'ㅕ':'u', 'ㅖ':'P', 'ㅗ':'h', 'ㅘ':'hk', 'ㅙ':'ho', 'ㅚ':'hl',
           'ㅛ':'y', 'ㅜ':'n', 'ㅝ':'nj', 'ㅞ':'np', 'ㅟ':'nl', 'ㅠ':'b',  'ㅡ':'m', 'ㅢ':'ml', 'ㅣ':'l',
           'ㄳ':'rt', 'ㄵ':'sw', 'ㄶ':'sg', 'ㄺ':'fr', 'ㄻ':'fa', 'ㄼ':'fq', 'ㄽ':'ft', 'ㄾ':'fx', 'ㄿ':'fv', 'ㅀ':'fg', 'ㅄ':'qt'}

def keng(kwd):
    return ''.join([keyboard[w] if w in keyboard else w for w in kwd])

# %%
sd['keyword_Eng'] = sd['자소분리'].apply(lambda x: keng(x) if type(x) == str else x)

# %% [markdown]
# 결과 예시

# %%
sd[['keyword', '자소분리', 'keyword_Eng']].sample(3)
# Out:
#            keyword              자소분리       keyword_Eng
# 54004         구딸파리         ㄱㅜㄸㅏㄹㅍㅏㄹㅣ         rnEkfvkfl
# 137776  c204msg594        c204msg594        c204msg594
# 59301      알로앤루 내복  ㅇㅏㄹㄹㅗㅇㅐㄴㄹㅜ ㄴㅐㅂㅗㄱ  dkffhdosfn soqhr

# %% [markdown]
# ## 영어 → 한글로 변환

# %% [markdown]
# 1. 영문-한글 키보드 딕셔너리 생성

# %%
cons = {'r':'ㄱ', 'R':'ㄲ', 's':'ㄴ', 'e':'ㄷ', 'E':'ㄸ', 'f':'ㄹ', 'a':'ㅁ', 'q':'ㅂ', 'Q':'ㅃ', 't':'ㅅ', 'T':'ㅆ',
           'd':'ㅇ', 'w':'ㅈ', 'W':'ㅉ', 'c':'ㅊ', 'z':'ㅋ', 'x':'ㅌ', 'v':'ㅍ', 'g':'ㅎ'}

vowels = {'k':'ㅏ', 'o':'ㅐ', 'i':'ㅑ', 'O':'ㅒ', 'j':'ㅓ', 'p':'ㅔ', 'u':'ㅕ', 'P':'ㅖ', 'h':'ㅗ', 'hk':'ㅘ', 'ho':'ㅙ', 'hl':'ㅚ',
           'y':'ㅛ', 'n':'ㅜ', 'nj':'ㅝ', 'np':'ㅞ', 'nl':'ㅟ', 'b':'ㅠ',  'm':'ㅡ', 'ml':'ㅢ', 'l':'ㅣ'}

cons_double = {'rt':'ㄳ', 'sw':'ㄵ', 'sg':'ㄶ', 'fr':'ㄺ', 'fa':'ㄻ', 'fq':'ㄼ', 'ft':'ㄽ', 'fx':'ㄾ', 'fv':'ㄿ', 'fg':'ㅀ', 'qt':'ㅄ'}

# %% [markdown]
# 2. 영문을 한글로 변환 & 한글 자모 결합

# %%
#! pip install hangul-utils
from hangul_utils import join_jamos

def engkor(text):
    result = ''   # 영 > 한 변환 결과
    
    # 1. 해당 글자가 자음인지 모음인지 확인
    vc = ''   # 자모순서
    for t in text:
        if t in cons :   # 자음에 있으면 'c'
            vc+='c'
        elif t in vowels:   # 모음에 있으면 'v'
            vc+='v'
        else:   # 둘 다 아니면 '!'
            vc+='!'

    # cvv → fVV / cv → fv / cc → dd 
    vc = vc.replace('cvv', 'fVV').replace('cv', 'fv').replace('cc', 'dd')

    i = 0
    while i < len(text):
        v = vc[i]
        t = text[i]

        j = 1
        # 한글일 경우
        try:
            if v == 'f' or v == 'c':   # 초성(f) & 자음(c) = 자음
                result+=cons[t]

            elif v == 'V':   # 더블 모음
                result+=vowels[text[i:i+2]]
                j+=1

            elif v == 'v':   # 모음
                result+=vowels[t]

            elif v == 'd':   # 더블 자음
                result+=cons_double[text[i:i+2]]
                j+=1
                
            else:
                result+=t
        
        # 한글이 아닌경우
        except:
            if v in cons:
                result+=cons[t]
            elif v in vowels:
                result+=vowels[t]
            else:
                result+=t
        
        i += j

    # 자모결합
    return join_jamos(result)

# %%
engkor('ekfrrktmatkf')
# Out:
# '닭가슴살'

# %%
sd['engkor'] = sd['keyword'].apply(lambda x: engkor(x) if type(x)==str else '')

# %% [markdown]
# 3. 영문으로만 이루어진 키워드 찾기
# 영어가 포함된 한글 키워드도 어중간하게 변화되어버렸다.
# 해당 키워드들을 구분짓기 위해 영문으로만 구성된 키워드를 표시해둔다.

# %%
# 영문으로만 이루어진 키워드 찾기
com = re.compile('^[a-zA-Z0-9]+$')
sd['eng'] = sd['keyword'].apply(lambda x : 'eng' if type(x) == str and com.search(x)!= None else 'not')

# %% [markdown]
# 내보내기

# %%
#sd.to_excel('한영변환_210129.xlsx', index = False)
